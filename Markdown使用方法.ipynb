# %% [markdown]
# 这是一条文字内容。
#
# **这是一条加粗文字内容。**
#
# *这是一条斜体文字内容。*
# _这也是一条斜体文字内容。_
#
# ps: 左右两星号加粗，左右_星号或_斜体

# %% [markdown]
# 双星号 <>里面加font color = red 红色+加粗<>里面加/font 双星号

# %% [markdown]
# **<font color = red>红色+加粗</font>**

# %% [markdown]
# ***<font color = green> 绿色+加粗+斜体 </font>***

# %% [markdown]
# # 改变字体（face）、大小(size)
#
# <>里面加font color=steel size=5 face=雅黑 这四个参数 5号雅黑 接着<>里面加/font
#
# **5号雅黑**
# <font color=steel size=5 face=雅黑>5号雅黑</font>
#
# - clor,size,font的顺序可以任意调整，且参数不需加引号

# %% [markdown]
# ```
#
# <font face="黑体">我是黑体字</font>
# <font face="微软雅黑">我是微软雅黑</font>
# <font face="STCAIYUN">我是华文彩云</font>
# <font color=red>我是红色</font>
# <font color=#008000>我是绿色</font>
# <font color=Blue>我是蓝色</font>
# <font size=5>我是尺寸</font>
# <font face="黑体" color=green size=5>我是黑体，绿色，尺寸为5</font>
#
# <table><tr><td bgcolor=yellow>背景色yellow</td></tr></table>
#
# <center>居中</center>
# <p align="left">左对齐</p>
# <p align="right">右对齐</p>
#
#
# 使用HTML中下标下标的语法即可, 语法：
# H<sub>2</sub>O  CO<sub>2</sub>
# 爆米<sup>TM</sup>
#
# ```

# %%
# 文字进行高亮显示

'''
-通过<mark>标签  左右各一个<mark>，中间写 ：黄色高亮
 <mark>黄色高亮<mark>
 
-改变高亮颜色 里面参数写：<>里面写mark 接着写：style=background-color:red 文字 末尾加：<>l里面写/mark
 <mark style=background-color:red>改变高亮颜色</mark>

-叠加字体的变化
 <mark><font color=red size=4 face=雅黑>叠加字体的变化<font><mark>
'''

# %% [markdown]
# # 文字进行高亮显示
#
# -通过<mark>标签  左右各一个，中间写 ：黄色高亮
#  <mark>黄色高亮<mark>
#
# -改变高亮颜色 里面参数写：<>里面写mark 接着写：style=background-color:red 文字 末尾加：<>l里面写/mark
#  <mark style=background-color:red>改变高亮颜色</mark>
#
# -叠加字体的变化
#  <mark><font color=red size=4 face=雅黑>叠加字体的变化<font><mark>

# %% [markdown]
# # 引用
#
# >知之为知之，不知为不知，是知也。
#
# ps: 空白行加上>  , shift+回车 , 会加边框条纹 如上

# %% [markdown]
# # 换行
# **在一行的末尾添加两个或多个空格，然后按回车 或者 末尾加 尖括号br标签 **
#
# 你好<br>
# 胡腾
# 我在武汉

# %% [markdown]
# # 标题
#
# ## 一级标题
#
# ## 二级标题
#
# #######
#
# ps:#后空一格才会标题  ，7个#不会显示加粗 同理shift+回车

# %% [markdown]
# # 序列表
#
# **在行首使用数字加 . 可以构建列表。
#
# 1.一个
#
# 2.二个
#
# 3.三个

# %% [markdown]
# # 无序列表
#
# **在行首使用 - , + 或者 * 可以创建无序列表。
#
# - 一个
#
# - 二个
#
# - 三个
#
# + 四个
#
# * 五个

# %% [markdown]
# # 表格
#
# **你可以使用 | 和 - 符号在Markdown中构建表格。
#
# |名称|价格|数量|
# |--|--|--|
# |苹果|12|100|
# |栗子|15|200|

# %% [markdown]
# 表格：
# 表头|表头|表头
# ---|:--:|---:
# 内容|内容|内容
# 内容|内容|内容
#
# 第二行分割表头和内容。
# - 有一个就行，为了对齐，多加了几个
# 文字默认居左
# -两边加：表示文字居中
# -右边加：表示文字居右
# 注：原生的语法两边都要用 | 包起来。此处省略

# %% [markdown]
# # 代码块

# %% [markdown]
# `代码内容`
#
# 代码块：代码之间分别用三个反引号包起来，且两边的反引号单独占一行
# (```)
#   代码...
#   代码...
#   代码...
# (```)

# %% [markdown]
# 反引号在数字1左边 英文输入 按一下
#
# `python`
#
# ```
# 你好啊
# ```

# %% [markdown]
# # 分隔线语法
# 三个或多个星号***、破折号---或下划线___
#
# ***
#
# 可以可以

# %% [markdown]
# # 公式
#
# 可以编写**行内公式** 美元符号e^{i\pi} + 1 = 0美元符号 会被渲染成

# %% [markdown]
# $e^{i\pi} + 1 = 0$

# %% [markdown]
# **行间公式**
#
# 两美元符号
# E = MC^2
# 两美元符号

# %% [markdown]
# $$
# E = MC^2
# $$

# %% [markdown]
# # 链接
#
# 搜索引擎包括：[百度](http://baidu.com/),[必应](http://bing.com/),[谷歌](http://google.com/).
#
# ps:使用 [名称](链接）

# %% [markdown]
# 尖括号里面放url或者email地址变成可点击的链接<br>
# < https://yiyan.baidu.com/><br>
# <2388817362@qq.com>

# %% [markdown]
# **带格式化的链接**
#
# **强调链接** ,在链接语法前后增加星号。要将链接表示为代码，请在方括号中添加反引号。
#
# 就是：两星【名称】（链接地址）两星
#
# I love the website, **[hello](https://www.hello-algo.com/)**!

# %% [markdown]
# # 图片
#
# !中括号里面Ipy header(图片链接)
#
# 网络图片可以写入图片链接显示
# ![Ipy header](https://www.hello-algo.com/index.assets/conceptual_rendering.png)
#
# 本地图片可以使用相对路径显示
# ![Ipy header](./1686994288848.jpg)
#
# 本地图片拖入自动生成附件图片链接：
# ![1686994288848.jpg](attachment:1686994288848.jpg)

# %% [markdown]
# # 导出文件
#
# file -> download as
